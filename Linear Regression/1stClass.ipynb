# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('cars24_new_clean.csv')
df.sample(frac=1).head()
# Out:
#       Year  Kilometers_Driven  Mileage  Engine   Power     Seats  Price  \
# 4842  2014              33000    20.00    1399   68.05  5.000000   3.25
# 2568  2010              74213    14.84    2143  170.00  5.000000  11.50
# 3087  2014              74663    33.54     998   67.04  5.000000   3.25
# 1306  2015              50295    16.10    1000   70.00  5.278735   5.80
# 3356  2014              49000    17.40    1497  117.30  5.000000   4.75
#
#                make                   model  Transmission  ...  \
# 4842           Ford    Figo Diesel Titanium          True  ...
# 2568  Mercedes-Benz  New C-Class 220 CDI AT         False  ...
# 3087         Maruti         Wagon R CNG LXI          True  ...
# 1306         Maruti           Swift 1.3 ZXI          True  ...
# 3356          Honda          City i VTEC SV          True  ...
#
#       location_Hyderabad  location_Jaipur  location_Kochi  location_Kolkata  \
# ...

# %%
#Price as selling price is given for particular car as Target Variable
#All the other variables are used inorder to make the prediction

# %%
#Define X and Y
X=df['Power'].values
Y=df['Price'].values

#normalisation - u = X.mean(); std = X.std(); X = (X-u)/std

#Visualize
plt.scatter(X,Y)
plt.xlabel('Max_Power')
plt.ylabel('Selling_Price')
plt.show()

# %%
#Lets define Function first

# %%
def univariable_linear_hypothesis(x,theta):
    y_hat=theta[0]+theta[1]*x
    return y_hat

# %%
#Now we need to define our cost function

# %%
def cost(X,Y,theta):
    m=X.shape[0] #number of training examples
    total_error=0.0
    for i in range(m):
        y_=univariable_linear_hypothesis(x[i],theta)
        total_error+=(y_ - Y[i])**2
    return (total_error/m)

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\style\core.py:137, in use(style)
#     136 try:
# --> 137     style = _rc_params_in_file(style)
#     138 except OSError as err:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:870, in _rc_params_in_file(fname, transform, fail_on_error)
#     869 rc_temp = {}
# --> 870 with _open_file_or_url(fname) as fd:
#     871     try:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\contextlib.py:137, in _GeneratorContextManager.__enter__(self)
#     136 try:
# --> 137     return next(self.gen)
#     138 except StopIteration:
#
# File ~\AppData\Local\Programs\Python\Python311\Lib\site-packages\matplotlib\__init__.py:847, in _open_file_or_url(fname)
#     846 fname = os.path.expanduser(fname)
# ...

# %%
import seaborn

# %%
X=np.arange(10)
Y=(X-5)**2 ## x=5 cost function will give minimum(0)
plt.style.use("seaborn-v0_8")
plt.plot(X,Y)
plt.ylabel("y = f(X)")
plt.xlabel("X")
plt.title("Convex Function y = (x-5)**2") #assume ground truth value is 5
plt.show()

# %%
print(plt.style.available)
# Out:
# ['Solarize_Light2', '_classic_test_patch', '_mpl-gallery', '_mpl-gallery-nogrid', 'bmh', 'classic', 'dark_background', 'fast', 'fivethirtyeight', 'ggplot', 'grayscale', 'seaborn-v0_8', 'seaborn-v0_8-bright', 'seaborn-v0_8-colorblind', 'seaborn-v0_8-dark', 'seaborn-v0_8-dark-palette', 'seaborn-v0_8-darkgrid', 'seaborn-v0_8-deep', 'seaborn-v0_8-muted', 'seaborn-v0_8-notebook', 'seaborn-v0_8-paper', 'seaborn-v0_8-pastel', 'seaborn-v0_8-poster', 'seaborn-v0_8-talk', 'seaborn-v0_8-ticks', 'seaborn-v0_8-white', 'seaborn-v0_8-whitegrid', 'tableau-colorblind10']

# %%
#Now how to Iterate through gradient
import time
#matplotlib notebook

fig=plt.figure()
ax=fig.add_subplot(111)
plt.ion()

x=0.5
y=(x-5)**2 ## Assume Ground truth value is 5
plt.plot(X,Y)
plt.scatter(x,y)
plt.ylabel("y = f(X)")
plt.xlabel("X")
plt.title("Gradient Descent - 50 Stops in downhill direction")

lr=0.1
errors=[]
#10 steps int he downhill direction
for i in range(10):
    grad=2*(x-5)
    x=x-grad
    y=(x-5)**2
    error=y-0
    errors.append(error)
    plt.scatter(x,y)
    fig.canvas.draw()
    time.sleep(0.5)
plt.show()

# %%
import time
#matplotlib notebook

fig=plt.figure()
ax=fig.add_subplot(111)
plt.ion()

x=0.5
y=(x-5)**2 ## Assume Ground truth value is 5
plt.plot(X,Y)
plt.scatter(x,y)
plt.ylabel("y = f(X)")
plt.xlabel("X")
plt.title("Gradient Descent - 50 Stops in downhill direction")
