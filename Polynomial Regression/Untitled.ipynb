# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
np.random.seed(1)
x=np.random.rand(50,1)
y=0.7*(x**5) - \
  2.1*(x**4) + \
  2.3*(x**3) + \
  0.2*(x**2) + \
  0.3*x + \
  0.4*np.random.rand(50,1) #no data in world is perfect
fig=plt.figure()
plt.scatter(x,y)
plt.ylabel("y")
plt.xlabel("x")
plt.show()

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

# %%
#There are some parameter
#Bydefault normalize=False
 #Bydefault we are normalizing the data upfront ad passing thaat when we actually passing model.fit
#we are passing raw dataas it is
#and we want linear regression to normalize it

# %%
model=LinearRegression()
model.fit(x,y)
output=model.predict(x)

fig=plt.figure()
plt.scatter(x,y,label="data")
plt.scatter(x,output,label="prediction")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
display(model.score(x,y))
# Out:
# 0.8919326382437994

# %%
#Since 0.89 as R^2 is good things for this linear regssion
#Now Introducting the Polynomial term

# %%
#A polynomial Regression Model of Degree 2
X_deg2=np.hstack([x,x**2])
model=LinearRegression()
model.fit(X_deg2,y)

output=model.predict(X_deg2)

fig=plt.figure()
plt.scatter(x,y,label="data")
plt.scatter(x,output,label="prediction")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
display(model.score(X_deg2,y))
# Out:
# 0.937213227713278

# %%
#Since a polynomail eqn of order 2 giving us R^2 as 0.93
#So which one you think 
#Whether A Linear Regression or Polynomrial one is better fit for our model

#Obviously Polynomial Regression

# %%
#A Polynomial Regression Model of Degree 3
X_deg3=np.hstack([x,x**2,x**3])
model=LinearRegression()
model.fit(X_deg3,y)

output=model.predict(X_deg3)

fig=plt.figure()
plt.scatter(x,y,label="data")
plt.scatter(x,output,label="prediction")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
display(model.score(X_deg3,y))
# Out:
# 0.9384895307987051

# %%
#Not much But there is very slight improvemeent happened at polynomail of degree3 instead of deg2

# %%
#This is raw methodology now lets use inbuilt methdologies

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

scaler=StandardScaler()
poly=PolynomialFeatures()

# %%
#Since phle humlog Numpy array ke madad se krrhe the now we will do it on our own

# %%
X_poly=PolynomialFeatures()
#Bydefault ye polynomial Regression me hai like Degree=2,interaction_only=False,include_bias=True,order='C'

# %%
#What each of this features is ? 
#When we use a model there are tons of parameter in it doesnt mean that 
#every paraamter we have to use while building the paramater

#Iss Polynomail regression me sbse important degree wala paraamter hai

# %%
poly=PolynomialFeatures(2)

# %%
#We should also check Adjusted R2 like is it really improing your model by adding a term 
#Lets seee polynomail features
poly=PolynomialFeatures(2)

X_poly=poly.fit_transform(x)
X_poly_scaled=scaler.fit_transform(X_poly)

model=LinearRegression()
model.fit(X_poly_scaled,y)

print(model.score(X_poly_scaled,y))
#Ye bhi wahi R2 diya but humlog bas yaha inbuilt method use kiye the
# Out:
# 0.937213227713278

# %%
poly=PolynomialFeatures(3)  #olynomail Features upto Degree 3 

X_poly=poly.fit_transform(x)
X_poly_scaled=scaler.fit_transform(X_poly)

model=LinearRegression()
model.fit(X_poly_scaled,y)

print(model.score(X_poly_scaled,y))
# Out:
# 0.9384895307987051

# %%
#That;s how we do skicit learn implementation of Polynomail regression

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

scores=[]
for i in range(1,100):
    poly=PolynomialFeatures(i)
    X_poly=poly.fit_transform(x)
    scaler=StandardScaler()
    scaler.fit(X_poly)
    X_poly_scaled=scaler.transform(X_poly)
    model=LinearRegression()
    model.fit(X_poly_scaled,y)
    output=model.predict(X_poly_scaled)
    fig=plt.figure()
    plt.scatter(x,y,label="Samples")
    plt.scatter(x,output,label="Prediction")
    plt.xlabel("X")
    plt.ylabel("Y")
    plt.title(f"Degree {i}")
    plt.show()
    display(model.score(X_poly_scaled,y))
    scores.append(model.score(X_poly_scaled,y))
# Out:
# 0.8919326382437994
# 0.937213227713278
# 0.9384895307987051
# 0.9509958355607927
# 0.9515258649694077
# 0.9517050823795117
# 0.951924584842223
# 0.9525104796673565
# 0.9531232513749791
# 0.9550033299759495
# 0.955280504035908
# 0.9552866345827975
# 0.9567208941181086
# 0.9578882920636237
# 0.9594024815321641
# 0.9594043033815465
# 0.9621103298635383
# 0.962110479874733
# 0.9620887633716467
# 0.9620940703657912
# 0.9621394887613266
# 0.9623156512511299
# 0.9658161805462513
# 0.9656707123650085
# 0.9655224954127162
# 0.9656484834882755
# 0.9655229972520672
# 0.9654012885908543
# 0.965290949366234
# 0.9674457629347343
# 0.9673257311990983
# 0.9671841110385445
# 0.9670188444233925
# 0.9668328366870115
# 0.967259041711875
# 0.967174626414025
# 0.9670859950260817
# 0.9669911700773814
# 0.9668884158648366
# 0.9667771118531767
# 0.9666574677251593
# 0.9665277423269594
# 0.9683502972076408
# 0.968030815731407
# 0.9683387347927147
# 0.9683973924881106
# 0.9684287298863454
# 0.9684486625498362
# ...

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler

scores=[]
for i in range(1,40):
    poly=PolynomialFeatures(i)
    X_poly=poly.fit_transform(x)
    scaler=StandardScaler()
    scaler.fit(X_poly)
    X_poly_scaled=scaler.transform(X_poly)
    model=LinearRegression()
    model.fit(X_poly_scaled,y)
    output=model.predict(X_poly_scaled)
    scores.append(model.score(X_poly_scaled,y))
max_pol=np.argmax(scores)
print(max_pol,scores[max_pol])
# Out:
# 29 0.9674457629347343

# %%
#Going polynomail regression uptoo 30 is good things ??
#Am is correct? No Let me giev you the logi behin it

# %%
# R^2 - 0.951 order=5
# R^2 - 0.968 order=30

#Matlab 25 aitional Features and look at the increase like 0.167 additional 25 features doesn't make sense
#reemeber our golden rule of our model
# It trains from the data well and it is suppposed to perform well from the test data or unseen data
#So here going all the way upto 30 polynomail is not a goood way

#Now lets see by seperating the training and test data 
#we train the model with polynomial of 5 
#and train another model with polynomial of degree 30

#And compare the test performance of these two

# %%
#So far we are looking just training part howver
#Just looking at training part doesnt make sense so generalization actually makes sense

# %%
np.random.seed(1)
x=np.random.rand(100,1)
y = 0.7*(x**5) - \
    2.1*(x**4) + \
    2.3*(x**3) + \
    0.2*(x**2) + \
    0.3*x + \
    0.4*np.random.rand(100,1)  # Change 50 to 100



from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %%
plt.scatter(X_train,Y_train)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
plt.scatter(X_test,Y_test)
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
#Since we have very less data on test because we taking just 20% of my 100

# %%
#Lets try to fit a model on training data and see how the model scores on test data 
#So we can actually tells that how the model is going to do better on unseen data

# %%
#A model perfromance is geenrally checed on the unseen data

# %%
#If it perfroms very on unseen data then we can say generalization is better for it

# %%
#Generalization ka matlab ye hota ki 
#Learn once and give good prediction on differnet unseen data 
#Ill do that by compairng the models

# %% [markdown]
# ## New concepts

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler  # If using scaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

degree = 5
scaler = StandardScaler()  # Ensure scaler is defined
polyreg_scaled = make_pipeline(PolynomialFeatures(degree), scaler, LinearRegression())

polyreg_scaled.fit(X_train, Y_train)
display(polyreg_scaled.score(X_train, Y_train))
display(polyreg_scaled.score(X_test,Y_test))
#It is perfect example of low bias and low variance model(Moderate Model )
# Out:
# 0.9214962587812688
# 0.8656262710391982

# %%
#make_pipeline=A pipeline is a sequence of steps

# %%
###Sequence :Create polynomial Features, Scales the data , Train the fit 
#So basically we a combining all the upper features into one by using the make_pipeline

# %%
#Creating polynomialFeature bhi hogya usme as of degree 5
#we are standardrizing the data using the scaler fucntion
#Phir training me LinearRegression() bhi likh diye hai

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler  # If using scaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

degree = 30
scaler = StandardScaler()  # Ensure scaler is defined
polyreg_scaled = make_pipeline(PolynomialFeatures(degree), scaler, LinearRegression())

polyreg_scaled.fit(X_train, Y_train)
display(polyreg_scaled.score(X_train, Y_train))
display(polyreg_scaled.score(X_test,Y_test))
#It is perfect example of overfitted model
# Out:
# 0.9368834431483393
# 0.8041303507356152

# %%
#Jab hum polynomial ko increase krdiye the to ye r2 ka core badha hai 
#us degree of 30 ke liye

# %%
#But on a test data set it just got worse my model of degree 5 giving me better result than model of degree 30

# %%
#Whenever we try to build a model we dotn judge a modle by looking a model that how it is erfroming on trained datatset

# %%
#We test it on test dataset

# %%
#Now this makes a very big qn ki wo polynomial of degree ka itna acha reult aaraha training data par
#Wahi model ka test data pe bekar aaraha aisa kyu

# %%
#Because higher degree polynomial would cut through more of datapoint
#this probelm is called as Overfitting

# %%
#Lets see what actually is overfitting

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler  # If using scaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

degree = 1
scaler = StandardScaler()  # Ensure scaler is defined
polyreg_scaled = make_pipeline(PolynomialFeatures(degree), scaler, LinearRegression())

polyreg_scaled.fit(X_train, Y_train)
display(polyreg_scaled.score(X_train, Y_train))
display(polyreg_scaled.score(X_test,Y_test))
#This is low variance (Underfitted Model)
# Out:
# 0.8740205794555178
# 0.8073308228555811

# %%
#NOTE-A overfitted model does well on Training but not so well on Unseen data

# %%
#Note -A underfitted is poor on training and on test it is more poorer

# %%
#Striking  a balance between the Underfitted and Overfitted is called as Bias Variinace Tradeoff

# %%
#In this case the correct tradeoff is what will be right degree of the polynomial
#that doesnt lead to overfiittingand also doesnt lead to underfitting

# %%
from sklearn.pipeline import make_pipeline
from sklearn.preprocessing import StandardScaler  # If using scaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

degrees = 32 #Because 30 pe maximum mila hai isliye 32 tak jaarhe hai
train_scores=[]
test_scores=[]
for degree in range(1,degrees):
    scaler = StandardScaler()  # Ensure scaler is defined
    polyreg_scaled = make_pipeline(PolynomialFeatures(degree), scaler, LinearRegression())
    polyreg_scaled.fit(X_train, Y_train)
    train_score=polyreg_scaled.score(X_train,Y_train)
    test_score=polyreg_scaled.score(X_test,Y_test)
    train_scores.append(train_score)
    test_scores.append(test_score)

# %%
plt.figure()
plt.plot(list(range(1,32)),train_scores,label="train")
plt.plot(list(range(1,32)),test_scores,label="test")
plt.legend(loc='lower right')
plt.xlabel("degree")
plt.ylabel("R-score")
plt.show()

# %%
#Since upto 3 or 4 polynomail our training performance and testing perfromnace has been increased and it remained same

# %%
#But after 4 the training performance is been increasing  not like before but yes it is increasing while the testing performanec after 4 starts decreasing

# %%
#So this is right spot like 4 or 5 pe correct hai anything after that is going to create more gaps ebtween training and testing

# %%
#So humlog kehsakte ki 4 tak jaane ke baad ye best rhega uske baad ka sahi nhi rhega
#This is very common qn in interview 
#like what is bias and what is variance and when do we say that our model is good like aise qn phuche jaate

# %% [markdown]
# ## Implementing K-Fold

# %%
from sklearn.model_selection import KFold
##number of fields
kf=KFold(n_splits=10)

from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

degrees=32 #number of data points
train_scores=[]
test_scores=[]

for degree in range(1,degrees):
    fold_train_scores=[]
    fold_test_scores=[]
    for train_index,test_index in kf.split(x):
        X_train,X_test=X[train_index],X[test_index]
        Y_train,Y_test=Y[train_index],Y[test_index]
        polyreg_scaled=make_pipeline(PolynomialFeatures(degrees),scaler,LinearRegression())
        polyreg_scaled.fit(X_train,Y_train)
        train_score=polyreg_scaled.score(X_train,Y_train)
        test_score=polyreg_scaled.score(X_test,Y_test)
        fold_train_scores.append(train_score)
        fold_test_scores.append(test_score)
    train_score=np.mean(fold_train_scores)
    test_score=np.mean(fold_test_scores)
    train_scores.append(train_score)
    test_scores.append(test_score)
plt.figure()
plt.plot(list(range(1,32)),np.log(train_scores),label="Train")
plt.plot(list(range(1,32)),np.log(test_scores),label="Test")
plt.legend(loc='lower right')
plt.xlabel("Degree")
plt.ylabel("R-Score")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[56], line 17
#      15 fold_test_scores=[]
#      16 for train_index,test_index in kf.split(x):
# ---> 17     X_train,X_test=X[train_index],X[test_index]
#      18     Y_train,Y_test=Y[train_index],Y[test_index]
#      19     polyreg_scaled=make_pipeline(PolynomialFeatures(degrees),scaler,LinearRegression())
#
# NameError: name 'X' is not defined

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression

# Ensure x and y are defined
np.random.seed(1)
x = np.random.rand(100, 1)
y = 0.7 * (x**5) - 2.1 * (x**4) + 2.3 * (x**3) + 0.2 * (x**2) + 0.3 * x + 0.4 * np.random.rand(100, 1)

X = x  # Assign to ensure correct variable usage
Y = y

# K-Fold cross-validation
kf = KFold(n_splits=10, shuffle=True, random_state=1)  # Shuffle added for better randomness
scaler = StandardScaler()  # Define scaler

degrees = 32  # Max polynomial degree
train_scores = []
test_scores = []

for degree in range(1, degrees):
    fold_train_scores = []
    fold_test_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        Y_train, Y_test = Y[train_index], Y[test_index]
        
        # Fix: Use 'degree' instead of 'degrees'
        polyreg_scaled = make_pipeline(PolynomialFeatures(degree), scaler, LinearRegression())
        polyreg_scaled.fit(X_train, Y_train)
        
        train_score = polyreg_scaled.score(X_train, Y_train)
        test_score = polyreg_scaled.score(X_test, Y_test)
        
        fold_train_scores.append(train_score)
        fold_test_scores.append(test_score)
    
    train_scores.append(np.mean(fold_train_scores))
    test_scores.append(np.mean(fold_test_scores))

# Plot results
plt.figure()
plt.plot(range(1, degrees), np.log(train_scores), label="Train")
plt.plot(range(1, degrees), np.log(test_scores), label="Test")
plt.legend(loc='lower right')
plt.xlabel("Degree")
plt.ylabel("Log R-Square Score")
plt.show()
# Out:
# C:\Users\Srija\AppData\Local\Temp\ipykernel_12376\744490225.py:48: RuntimeWarning: invalid value encountered in log
#   plt.plot(range(1, degrees), np.log(test_scores), label="Test")

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression

# Ensure x and y are defined
np.random.seed(1)
x = np.random.rand(100, 1)
y = 0.7 * (x**5) - 2.1 * (x**4) + 2.3 * (x**3) + 0.2 * (x**2) + 0.3 * x + 0.4 * np.random.rand(100, 1)

X = x  # Assign to ensure correct variable usage
Y = y

# K-Fold cross-validation
kf = KFold(n_splits=10)  # Shuffle added for better randomness
scaler = StandardScaler()  # Define scaler

degrees = 32  # Max polynomial degree
train_scores = []
test_scores = []

for degree in range(1, degrees):
    fold_train_scores = []
    fold_test_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        Y_train, Y_test = Y[train_index], Y[test_index]
        
        # Fix: Use 'degree' instead of 'degrees'
        polyreg_scaled = make_pipeline(PolynomialFeatures(degree), scaler, LinearRegression())
        polyreg_scaled.fit(X_train, Y_train)
        
        train_score = polyreg_scaled.score(X_train, Y_train)
        test_score = polyreg_scaled.score(X_test, Y_test)
        
        fold_train_scores.append(train_score)
        fold_test_scores.append(test_score)
    
    train_scores.append(np.mean(fold_train_scores))
    test_scores.append(np.mean(fold_test_scores))

# Plot results
plt.figure()
plt.plot(range(1, degrees), np.log(train_scores), label="Train")
plt.plot(range(1, degrees), np.log(test_scores), label="Test")
plt.legend(loc='lower right')
plt.xlabel("Degree")
plt.ylabel("Log R-Square Score")
plt.show()
# Out:
# C:\Users\Srija\AppData\Local\Temp\ipykernel_12376\3236597216.py:48: RuntimeWarning: invalid value encountered in log
#   plt.plot(range(1, degrees), np.log(test_scores), label="Test")

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression

# Ensure x and y are defined
np.random.seed(1)
x = np.random.rand(100, 1)
y = 0.7 * (x**5) - 2.1 * (x**4) + 2.3 * (x**3) + 0.2 * (x**2) + 0.3 * x + 0.4 * np.random.rand(100, 1)

X = x  # Assign to ensure correct variable usage
Y = y

# K-Fold cross-validation
kf = KFold(n_splits=10)  # Shuffle added for better randomness
scaler = StandardScaler()  # Define scaler

degrees = 32  # Max polynomial degree
train_scores = []
test_scores = []

for degree in range(1, degrees):
    fold_train_scores = []
    fold_test_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        Y_train, Y_test = Y[train_index], Y[test_index]
        
        # Fix: Use 'degree' instead of 'degrees'
        polyreg_scaled = make_pipeline(PolynomialFeatures(degree), scaler, LinearRegression())
        polyreg_scaled.fit(X_train, Y_train)
        
        train_score = polyreg_scaled.score(X_train, Y_train)
        test_score = polyreg_scaled.score(X_test, Y_test)
        
        fold_train_scores.append(train_score)
        fold_test_scores.append(test_score)
    
    train_scores.append(np.mean(fold_train_scores))
    test_scores.append(np.mean(fold_test_scores))

# Plot results
plt.figure()
plt.plot(range(1, degrees), train_scores, label="Train")
plt.plot(range(1, degrees), test_scores, label="Validation Avg Score")
plt.legend(loc='lower right')
plt.ylim(0,1)
plt.xlabel("Degree")
plt.ylabel("R-Square Score")
plt.show()

#we shouldn't be using log

# %%
#it is one iteration where R^2 is going quite -ve theoritically R^2 can be negative

# %%
#since 4 tak acha khasa gap so we can go upto polynomial of degree 4

# %%
import matplotlib.pyplot as plt
from sklearn.model_selection import KFold
from sklearn.preprocessing import PolynomialFeatures, StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.linear_model import LinearRegression

# Ensure x and y are defined
np.random.seed(1)
x = np.random.rand(100, 1)
y = 0.7 * (x**5) - 2.1 * (x**4) + 2.3 * (x**3) + 0.2 * (x**2) + 0.3 * x + 0.4 * np.random.rand(100, 1)

X = x  # Assign to ensure correct variable usage
Y = y

# K-Fold cross-validation
kf = KFold(n_splits=10,shuffle=True,random_state=1)#so we get consistently the same result
scaler = StandardScaler()  # Define scaler

degrees = 32  # Max polynomial degree
train_scores = []
test_scores = []

for degree in range(1, degrees):
    fold_train_scores = []
    fold_test_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        Y_train, Y_test = Y[train_index], Y[test_index]
        
        # Fix: Use 'degree' instead of 'degrees'
        polyreg_scaled = make_pipeline(PolynomialFeatures(degree), scaler, LinearRegression())
        polyreg_scaled.fit(X_train, Y_train)
        
        train_score = polyreg_scaled.score(X_train, Y_train)
        test_score = polyreg_scaled.score(X_test, Y_test)
        
        fold_train_scores.append(train_score)
        fold_test_scores.append(test_score)
    
    train_scores.append(np.mean(fold_train_scores))
    test_scores.append(np.mean(fold_test_scores))

# Plot results
plt.figure()
plt.plot(range(1, degrees), train_scores, label="Train")
plt.plot(range(1, degrees), test_scores, label="Validation Avg Score")
plt.legend(loc='lower right')
plt.ylim(0,1)
plt.xlabel("Degree")
plt.ylabel("R-Square Score")
plt.show()

# %%
#I dont see much of difference

# %%
#We dont have to add cross validation while suing Linear regreesion
#i will tell you the reason
#From tree based  concept onwards everytime when we build our model we will include cross validation
#That way we validate our model first to make sure that our model is decent first and with low bias and with low varinace
#then we jump into test dataset

# %%
np.random.seed(1)
x = np.random.rand(100, 1)
y = 0.7 * (x**5) - 2.1 * (x**4) + 2.3 * (x**3) + 0.2 * (x**2) + 0.3 * x + 0.4 * np.random.rand(100, 1)

X = x  # Assign to ensure correct variable usage
Y = y

# K-Fold cross-validation
kf = KFold(n_splits=10,shuffle=True,random_state=1)#so we get consistently the same result
scaler = StandardScaler()  # Define scaler

degrees = 32  # Max polynomial degree
train_scores = []
test_scores = []
train_std=[]
test_std=[]

for degree in range(1, degrees):
    fold_train_scores = []
    fold_test_scores = []
    
    for train_index, test_index in kf.split(X):
        X_train, X_test = X[train_index], X[test_index]
        Y_train, Y_test = Y[train_index], Y[test_index]
        
        # Fix: Use 'degree' instead of 'degrees'
        polyreg_scaled = make_pipeline(PolynomialFeatures(degree), scaler, LinearRegression())
        polyreg_scaled.fit(X_train, Y_train)
        
        train_score = polyreg_scaled.score(X_train, Y_train)
        test_score = polyreg_scaled.score(X_test, Y_test)
        
        fold_train_scores.append(train_score)
        fold_test_scores.append(test_score)
    train_std_f=np.std(fold_train_scores)
    test_std_f=np.std(fold_test_scores)
    train_scores.append(np.mean(fold_train_scores))
    test_scores.append(np.mean(fold_test_scores))
    test_std.append(test_std_f)
    train_std.append(train_std_f)

# Plot results
plt.figure()
plt.plot(range(1, degrees), train_scores, label="Train")
plt.plot(range(1, degrees), test_scores, label="Validation Avg Score")
plt.legend(loc='lower right')
plt.ylim(0,1)
plt.xlabel("Degree")
plt.ylabel("R-Square Score")
plt.show()
train_std
# Out:
# [0.007107324067783755,
#  0.0026083702910495218,
#  0.0023263535579837306,
#  0.002368142141581429,
#  0.002414609228725516,
#  0.0024001528290185977,
#  0.0026680896956571046,
#  0.002718416547869053,
#  0.0026381158915382437,
#  0.0029733795686592724,
#  0.0024920063299839986,
#  0.002454507462158876,
#  0.0026137645379153375,
#  0.0028498093371998124,
#  0.0029266025372429094,
#  0.0029195472879848094,
#  0.0030592951130938694,
#  0.0030688339036843665,
#  0.0031838756115073904,
#  0.003145685779167562,
#  0.0031200019223174102,
#  0.003119240285639699,
#  0.003204434293724968,
#  0.003174584797146019,
#  0.003157811846666565,
#  0.003232465135572184,
#  0.00318273763734704,
#  0.003127443337580516,
#  0.0030701169918187538,
#  0.002959491794532607,
#  0.0029512304693342785]

# %%
#the question is will results vary scross the folds
#if it varies across the folds then in that case this std deviation of polynomail1 
#as 0.0071072... vala bahut bada hota

# %%
#Whenwe run a cross validaion we look a 2 things
# 1)Pehla main score ko dekhte 
# 2) standard deviation ko bhi dekhte

#By looking at std deviation we can say that the results are not varying a lot

# %%
 #Since it is very small thats why it is so fast
#if we try to use it as for large dataset and create k folds of then it will might be more of hours/days
#Cobine all this together sometime takes near to days
#Bootstrapping makes iyt even more slower
#This is designed in a way that it is slightly efficinent than we comapred it to bootstrapping

# %%
#Cross Validation is for observing that is it overfitting or is the resultr good
#How to control overfitting
#one of the famous technique for controlling overfitting is knwon as regularization

# %% [markdown]
# ## Regularization

# %% [markdown]
# #Regularization means penalizing the coefficient
#
# #suppos y = theta0 + theta1x1 + theta2*x2 + soon
# #This model can overfit due to two situation first one is lets say theta2 is unnecessary in the model
# #tha mean x2 has very limitd effect on y
# #When we ran our fit we included x2 so our model forcefull learnt some coefficient for theta2 and its not adding much value to model
# #So thats one reason for overfitting
#
#
# #2 the magnitutde of theta is higher than the required effect
# #when we say that matlab ki how theta is related to x theta <--X
# #Either a theta is altogether is not necessary or  a theta with lesser magnitude is better ftit for the model rather than something with higher magnitude
# #That why the name is penalizing the coefficient
# #Either by supressing them(matlab is coeff.. ko 0 krdiye so basically that feature is no more in model that way we are kicking out a variable form the model and making a model to lesser no of variabel and reducing the overfitting
#
#
# #2nd the magnitude is high we are supressing the coefficient so this is one way of feature selection
# #but through a method called penalization
#
#
# # we are not saying ki coefficint is very large and we are trying to cut it out
# # we are just saying that the coefficint is slighly higher than what it is supposed to be
# # A good example of iska is Multicollinearity
#
# # Like if both theta1 ad theat2 are present and x2 and x1 are string =ly corelated we can use vif and
# #by looking at vif we can kickout one of those variable we can iterate and see and make sure all these variabehave vid<0.5
# #Inspite of doing it lets say theta1 and theta2 is slightly higher which is responsibel for our overfitting so can we supress them
# #Jaha pe Coefficient hoga wahi pe Ye penalizing technqiue use hoga

# %% [markdown]
# ## Three Type of Penalizing Techniques

# %%
#1)LASSO
#2)Ridge
#3)Elasticnet

#-->It all boils down to cost fucntion 
#for our Linear regreesion :
#                           1/2m(sigma(i=1 to m)(htheta(x)-y)^2)
#and the unknowns which we need to func is theta0,theat1,theta2,,,and soon

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
X=np.arange(10)
Y=(X-5)**2 ##x=5 cost function will give minimum(theta)
plt.style.use("ggplot")
plt.plot(X,Y)
plt.ylabel("y=f(X)")
plt.xlabel("X")
plt.title("Conver Function y=(x-5)**2") ##Assuming ground truth value is 5
plt.show()

# %%
X=np.arange(10)
Y=(X-5)**2 + 2*X ##x=5 cost function will give minimum(theta)
plt.style.use("ggplot")
plt.plot(X,Y)
plt.ylabel("y=f(X)")
plt.xlabel("X")
plt.title("Conver Function y=(x-5)**2") ##Assuming ground truth value is 5
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet

np.random.seed(1)
X=np.random.rand(100,1)
y=2.7*(X**5) - \
  2.1*(X**4) + \
  2.3*(X**3) + \
  0.2*(X**2) + \
  0.3*X + \
  0.4*np.random.rand(100,1)

degree=10
poly=PolynomialFeatures(degree)
x_poly=poly.fit_transform(X)
x_poly_scaled=scaler.fit_transform(x_poly)

from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_splot(x_poly_scaled,y,test_size=0.2,random_state=1)

linear=LinearRegression()
linear.fit(X_train,y_train)
print("Linear model cost")
print(linear.coef_)

ridg=Ridge(alpha=1)
ridg.fit(X_train,y_train)
print("Ridge Regression Coefficients")
print(ridg.coef_)

lass=Lasso(alpha=1)
lasso.fit(X_train,y_train)
print("")
